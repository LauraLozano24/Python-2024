# %% [markdown]
# Susesión que converge a  ** e**

# %%
#sucesión que converge a  e
import numpy as np
e = []

for n in range(1,1000):     #acambiar os valores para ñla aproximacion mas cercana
    aprox =(1 + 1/n)**n
    e.append(aprox)
print(f'{n:7}{aprox:>18.15f}')

print('el valor de e con NUMPY es',np.e)
# Out:
#     999 2.716922574226647
# el valor de e con NUMPY es 2.718281828459045

# %% [markdown]
# ** calcular PI Leibniz**

# %%
import numpy as np

pi = []
aprox = 0

for n in range(1,1000):     #acambiar os valores para ñla aproximacion mas cercana
        aprox =aprox + ((-1)**(n+1)*1/(2*n-1))
        pi.append(aprox)
print(f'{n:7}{4*aprox:>18.15f}')

print('el valor de e con NUMPY es',np.e)
# Out:
#       1 1.000000000000000
#       2 0.666666666666667
#       3 0.866666666666667
#       4 0.723809523809524
#       5 0.834920634920635
#       6 0.744011544011544
#       7 0.820934620934621
#       8 0.754267954267954
#       9 0.813091483679719
#      10 0.760459904732351
#      11 0.808078952351398
#      12 0.764600691481833
#      13 0.804600691481833
#      14 0.767563654444796
#      15 0.802046413065486
#      16 0.769788348549357
#      17 0.800091378852387
#      18 0.771519950280959
#      19 0.798546977307986
#      20 0.772905951666960
#      21 0.797296195569399
#      22 0.774040381615911
#      23 0.796262603838133
#      24 0.774986008093452
#      25 0.795394171358758
#      26 0.775786328221503
#      27 0.794654252749805
#      28 0.776472434567987
#      29 0.794016294217110
#      30 0.777067141674737
#      31 0.793460584297688
#      32 0.777587568424672
#      33 0.792972183809287
#      34 0.778046810674959
#      35 0.792539564298147
# ...

# %% [markdown]
# SERIE DE TAYLOR

# %%
from sympy import symbols, cos
x = symbols('x')
cosx = cos(x)
print(cosx.series(x, n= 20))
print(cosx.series(x, n= 20).removeO())
# Out:
# 1 - x**2/2 + x**4/24 - x**6/720 + x**8/40320 - x**10/3628800 + x**12/479001600 - x**14/87178291200 + x**16/20922789888000 - x**18/6402373705728000 + O(x**20)
# -x**18/6402373705728000 + x**16/20922789888000 - x**14/87178291200 + x**12/479001600 - x**10/3628800 + x**8/40320 - x**6/720 + x**4/24 - x**2/2 + 1

# %%
from sympy import symbols, ln
x = symbols('x')
lnx = ln(x)
print(lnx.series(x, n= 20,x0=1))
print(lnx.series(x, n= 20, x0=1).removeO())
# Out:
# -1 - (x - 1)**2/2 + (x - 1)**3/3 - (x - 1)**4/4 + (x - 1)**5/5 - (x - 1)**6/6 + (x - 1)**7/7 - (x - 1)**8/8 + (x - 1)**9/9 - (x - 1)**10/10 + (x - 1)**11/11 - (x - 1)**12/12 + (x - 1)**13/13 - (x - 1)**14/14 + (x - 1)**15/15 - (x - 1)**16/16 + (x - 1)**17/17 - (x - 1)**18/18 + (x - 1)**19/19 + x + O((x - 1)**20, (x, 1))
# x + (x - 1)**19/19 - (x - 1)**18/18 + (x - 1)**17/17 - (x - 1)**16/16 + (x - 1)**15/15 - (x - 1)**14/14 + (x - 1)**13/13 - (x - 1)**12/12 + (x - 1)**11/11 - (x - 1)**10/10 + (x - 1)**9/9 - (x - 1)**8/8 + (x - 1)**7/7 - (x - 1)**6/6 + (x - 1)**5/5 - (x - 1)**4/4 + (x - 1)**3/3 - (x - 1)**2/2 - 1
